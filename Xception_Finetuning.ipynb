# %%
import os
import numpy as np
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras.layers import Input, Concatenate
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D,Dropout,BatchNormalization,Activation,Conv2D
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # 建立資料集

# %%
batch_size=32
img_shape=(224,224)
input_shape=(224,224,3)

train_data_dir = '/kaggle/input/traindataset/train'
test_data_dir = '/kaggle/input/testdataset/test/test'


train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,  
 
    validation_split=0.2,
    rotation_range=45,
    width_shift_range=0.2 , 
    height_shift_range=0.2 ,
    shear_range=0.2 ,
    zoom_range=0.2,  
    horizontal_flip=True,  
    vertical_flip=True  
)


train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=img_shape,
    batch_size=batch_size,
    subset='training',
    class_mode='categorical',  
)
val_generator=train_datagen.flow_from_directory(
    train_data_dir,
    target_size=img_shape,
    batch_size=batch_size,
    class_mode='categorical',  
    subset='validation'
)


test_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=img_shape,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle = False,
)
labels = train_generator.classes
class_weights = compute_class_weight('balanced', classes=np.unique(labels),y=labels)
class_weights_dict = dict(enumerate(class_weights))
# Out:
# Found 22343 images belonging to 50 classes.
# Found 5560 images belonging to 50 classes.
# Found 7002 images belonging to 50 classes.

# %% [markdown]
# # 建立模型

# %%
base_model = tf.keras.applications.Xception(
    include_top = False,
    weights = 'imagenet',
    input_shape=input_shape,
)
base_model.trainable=False
x=base_model.output
x=GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x=BatchNormalization()(x)
x=Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
output_layer=Dense(50,activation='softmax')(x)


model = tf.keras.Model(inputs = base_model.input, outputs = output_layer)

#model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step

# %%
from keras.callbacks import ReduceLROnPlateau, LearningRateScheduler
import math

@tf.function
def lr_scheduler(epoch, lr):
    if epoch % 8 == 0 and epoch != 0:
        lr = lr * 0.1
    if lr<1e-7:
        lr=1e-7
    return lr

# %%
my_callbacks=[
    tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            min_delta=0,
            patience=10,
            verbose=2,
            mode='auto'
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.1,
            patience=5,
            verbose=2,
            min_lr=1e-7,
            mode='auto'
    ),
    tf.keras.callbacks.ModelCheckpoint(
            filepath="/kaggle/working/Xception.h5",
            monitor='val_loss',
            verbose=0,
            save_best_only=True,
            save_freq='epoch'
    ),
    tf.keras.callbacks.LearningRateScheduler(lr_scheduler)
]

# %%
model.compile(optimizer = tf.keras.optimizers.Nadam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy',tf.keras.metrics.TopKCategoricalAccuracy(k=5,name='top_5_categorical_accuracy',dtype=None)])

# %%
epochs=30
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator,
    class_weight=class_weights_dict,
    verbose=1,
    callbacks=my_callbacks
)
# Out:
# Epoch 1/30
# 461/699 [==================>...........] - ETA: 2:36 - loss: 2.2831 - accuracy: 0.3775 - top_5_categorical_accuracy: 0.7048
# /opt/conda/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 699/699 [==============================] - ETA: 0s - loss: 2.0759 - accuracy: 0.4197 - top_5_categorical_accuracy: 0.7529
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 699/699 [==============================] - 585s 826ms/step - loss: 2.0759 - accuracy: 0.4197 - top_5_categorical_accuracy: 0.7529 - val_loss: 1.4504 - val_accuracy: 0.5410 - val_top_5_categorical_accuracy: 0.8748 - lr: 1.0000e-04
# Epoch 2/30
# 699/699 [==============================] - 375s 537ms/step - loss: 1.4727 - accuracy: 0.5485 - top_5_categorical_accuracy: 0.8833 - val_loss: 1.3306 - val_accuracy: 0.5757 - val_top_5_categorical_accuracy: 0.8977 - lr: 1.0000e-04
# Epoch 3/30
# 699/699 [==============================] - 372s 532ms/step - loss: 1.3295 - accuracy: 0.5900 - top_5_categorical_accuracy: 0.9042 - val_loss: 1.2410 - val_accuracy: 0.6070 - val_top_5_categorical_accuracy: 0.9054 - lr: 1.0000e-04
# Epoch 4/30
# 699/699 [==============================] - 370s 529ms/step - loss: 1.2613 - accuracy: 0.6116 - top_5_categorical_accuracy: 0.9126 - val_loss: 1.2252 - val_accuracy: 0.6153 - val_top_5_categorical_accuracy: 0.9131 - lr: 1.0000e-04
# Epoch 5/30
# 699/699 [==============================] - 376s 538ms/step - loss: 1.1739 - accuracy: 0.6294 - top_5_categorical_accuracy: 0.9252 - val_loss: 1.1862 - val_accuracy: 0.6180 - val_top_5_categorical_accuracy: 0.9182 - lr: 1.0000e-04
# Epoch 6/30
# 699/699 [==============================] - 377s 539ms/step - loss: 1.1433 - accuracy: 0.6374 - top_5_categorical_accuracy: 0.9279 - val_loss: 1.1852 - val_accuracy: 0.6194 - val_top_5_categorical_accuracy: 0.9218 - lr: 1.0000e-04
# Epoch 7/30
# 699/699 [==============================] - 364s 521ms/step - loss: 1.1033 - accuracy: 0.6496 - top_5_categorical_accuracy: 0.9355 - val_loss: 1.1551 - val_accuracy: 0.6263 - val_top_5_categorical_accuracy: 0.9210 - lr: 1.0000e-04
# Epoch 8/30
# 699/699 [==============================] - 364s 521ms/step - loss: 1.0862 - accuracy: 0.6554 - top_5_categorical_accuracy: 0.9385 - val_loss: 1.1354 - val_accuracy: 0.6385 - val_top_5_categorical_accuracy: 0.9279 - lr: 1.0000e-04
# Epoch 9/30
# 699/699 [==============================] - 365s 523ms/step - loss: 0.9930 - accuracy: 0.6827 - top_5_categorical_accuracy: 0.9467 - val_loss: 1.0897 - val_accuracy: 0.6478 - val_top_5_categorical_accuracy: 0.9335 - lr: 1.0000e-05
# Epoch 10/30
# 699/699 [==============================] - 363s 519ms/step - loss: 0.9628 - accuracy: 0.6909 - top_5_categorical_accuracy: 0.9514 - val_loss: 1.0947 - val_accuracy: 0.6500 - val_top_5_categorical_accuracy: 0.9284 - lr: 1.0000e-05
# Epoch 11/30
# 699/699 [==============================] - 357s 511ms/step - loss: 0.9630 - accuracy: 0.6927 - top_5_categorical_accuracy: 0.9509 - val_loss: 1.0902 - val_accuracy: 0.6460 - val_top_5_categorical_accuracy: 0.9297 - lr: 1.0000e-05
# Epoch 12/30
# 699/699 [==============================] - 357s 511ms/step - loss: 0.9484 - accuracy: 0.6998 - top_5_categorical_accuracy: 0.9492 - val_loss: 1.0727 - val_accuracy: 0.6559 - val_top_5_categorical_accuracy: 0.9286 - lr: 1.0000e-05
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-07.
# 699/699 [==============================] - 365s 522ms/step - loss: 0.8983 - accuracy: 0.7136 - top_5_categorical_accuracy: 0.9581 - val_loss: 1.0636 - val_accuracy: 0.6574 - val_top_5_categorical_accuracy: 0.9360 - lr: 1.0000e-07
# Epoch 25/30
# 699/699 [==============================] - 359s 513ms/step - loss: 0.8948 - accuracy: 0.7124 - top_5_categorical_accuracy: 0.9599 - val_loss: 1.0782 - val_accuracy: 0.6536 - val_top_5_categorical_accuracy: 0.9324 - lr: 1.0000e-07
# Epoch 26/30
# 699/699 [==============================] - 362s 518ms/step - loss: 0.9102 - accuracy: 0.7093 - top_5_categorical_accuracy: 0.9564 - val_loss: 1.0739 - val_accuracy: 0.6540 - val_top_5_categorical_accuracy: 0.9326 - lr: 1.0000e-07
# Epoch 27/30
# 699/699 [==============================] - 358s 513ms/step - loss: 0.9024 - accuracy: 0.7140 - top_5_categorical_accuracy: 0.9558 - val_loss: 1.0683 - val_accuracy: 0.6576 - val_top_5_categorical_accuracy: 0.9336 - lr: 1.0000e-07
# Epoch 28/30
# 699/699 [==============================] - 362s 518ms/step - loss: 0.8975 - accuracy: 0.7111 - top_5_categorical_accuracy: 0.9551 - val_loss: 1.0738 - val_accuracy: 0.6556 - val_top_5_categorical_accuracy: 0.9324 - lr: 1.0000e-07
# Epoch 29/30
# 699/699 [==============================] - 361s 517ms/step - loss: 0.9055 - accuracy: 0.7086 - top_5_categorical_accuracy: 0.9569 - val_loss: 1.0695 - val_accuracy: 0.6516 - val_top_5_categorical_accuracy: 0.9326 - lr: 1.0000e-07
# Epoch 29: early stopping

# %% [markdown]
# # 畫出accuracy 以及loss curve

# %%
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.title('loss curve')
plt.ylabel('loss')
plt.legend()
plt.show()
plt.plot(history.history['accuracy'],label='accuracy')
plt.plot(history.history['val_accuracy'],label='val_accuracy')
plt.title('accuracy curve')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Classification report 和Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.utils import to_categorical
class_indices = train_generator.class_indices


test_predictions = model.predict(test_generator)

predicted_labels = np.argmax(test_predictions, axis=1)
predicted_class_names = [list(class_indices.keys())[i] for i in predicted_labels]
true_labels=test_generator.classes
true_class_names = [list(class_indices.keys())[i] for i in true_labels]

cm = confusion_matrix(true_class_names, predicted_class_names)


plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",  
            xticklabels=list(class_indices.keys()), 
            yticklabels=list(class_indices.keys()))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 219/219 [==============================] - 77s 350ms/step

# %%
report = classification_report(predicted_class_names, true_class_names)
print(report)
# Out:
#                               precision    recall  f1-score   support
#
#         Ants_Climbing_a_Tree       0.70      0.69      0.69       127
#       Assorted_Fried_Noodles       0.76      0.66      0.71       181
#                       Banana       0.99      0.98      0.98       161
#                 Bean_Sprouts       0.80      0.87      0.83       151
#     Black_Pepper_Pork_Fillet       0.49      0.47      0.48       143
#          Braised_Chicken_Leg       0.80      0.73      0.76       184
#                      Cabbage       0.81      0.69      0.74       144
#        Carrot_Scrambled_Eggs       0.70      0.83      0.76       131
#                Cherry_Tomato       0.94      0.89      0.91       180
#          Corn_Scrambled_Eggs       0.84      0.77      0.80       151
#           Crispy_Fish_Fillet       0.79      0.87      0.83       153
#                Curry_Chicken       0.56      0.54      0.55       159
#               Fushan_Lettuce       0.42      0.15      0.22        74
#           Garlic_Pork_Slices       0.36      0.49      0.42        95
#                Goose_Cabbage       0.59      0.61      0.60       135
#                        Grape       0.91      0.95      0.93       134
#               Hakka_Stir-Fry       0.63      0.58      0.60       168
#       Hollow_Heart_Vegetable       0.63      0.70      0.66       147
#                       Jujube       0.88      0.83      0.85       183
#                         Kale       0.58      0.27      0.37       183
#              Mainland_Sister       0.34      0.51      0.41        97
#              Mandarin_Orange       0.69      0.72      0.71       137
#                    Mapo_Tofu       0.62      0.59      0.60       149
#                  Marbled_Egg       0.82      0.79      0.80       161
#                    McNuggets       0.94      0.84      0.89       145
#                   Melon_Pork       0.64      0.77      0.70       133
#            Napa_Cabbage_Stew       0.56      0.55      0.56       122
#                         Oden       0.77      0.68      0.72       154
#         Onion_Scrambled_Eggs       0.60      0.64      0.62       115
#                       Orange       0.75      0.77      0.76       151
#            Organic_Baby_Kale       0.23      0.31      0.27        97
#    Organic_Qing_Pine_Cabbage       0.39      0.41      0.40        95
#                       Papaya       0.91      0.88      0.90       168
#                    Pineapple       0.83      0.80      0.82       151
#        Potato_Stew_with_Meat       0.67      0.48      0.56       193
#                Qingjiang_Cai       0.53      0.41      0.46       157
#                     Rapeseed       0.21      0.32      0.25        94
#      Salt_and_Pepper_Chicken       0.70      0.78      0.73       135
#            Satay_Pork_Slices       0.20      0.27      0.23        92
#           Sesame_Oil_Chicken       0.39      0.57      0.46       106
#                    Spaghetti       0.53      0.64      0.58       135
#                      Spinach       0.51      0.55      0.53       143
#                  Steamed_Egg       0.73      0.72      0.73       129
#       Sweet_and_Sour_Chicken       0.37      0.40      0.38       140
#            Three_Cup_Chicken       0.45      0.43      0.44       138
#        Tomato_Scrambled_Eggs       0.78      0.68      0.73       144
# Tower_Fragrance_Sea_Mushroom       0.74      0.70      0.72       145
#                   Watermelon       0.82      0.86      0.84       153
#                    Wax_Apple       0.93      0.89      0.91       114
#                   White_Rice       0.94      0.95      0.95       125
#
#                     accuracy                           0.67      7002
#                    macro avg       0.66      0.65      0.65      7002
#                 weighted avg       0.68      0.67      0.67      7002

# %% [markdown]
# # 畫出Top 5 Accuracy curve

# %%
plt.plot(history.history['top_5_categorical_accuracy'])
plt.plot(history.history['val_top_5_categorical_accuracy'])
plt.title('Model top_5_categorical_accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'],loc='upper left')
plt.show()
